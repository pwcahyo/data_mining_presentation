# %%
import sys

from itertools import chain, combinations
from collections import defaultdict
from optparse import OptionParser
from openpyxl import load_workbook
from operator import mul
import pandas as pd

# %%
def subsets(arr):
    """ Returns non empty subsets of arr"""
    return chain(*[combinations(arr, i + 1) for i, a in enumerate(arr)])


def returnItemsWithMinSupport(itemSet, transactionList, minSupport, freqSet):
        """calculates the support for items in the itemSet and returns a subset
       of the itemSet each of whose elements satisfies the minimum support"""
        _itemSet = set()
        localSet = defaultdict(int)

        for item in itemSet:
                for transaction in transactionList:
                        if item.issubset(transaction):
                                freqSet[item] += 1
                                localSet[item] += 1

        for item, count in localSet.items():
                support = float(count)/len(transactionList)

                if support >= minSupport:
                        _itemSet.add(item)

        return _itemSet


def joinSet(itemSet, length):
        """Join a set with itself and returns the n-element itemsets"""
        return set([i.union(j) for i in itemSet for j in itemSet if len(i.union(j)) == length])


def getItemSetTransactionList(data_iterator):
    transactionList = list()
    itemSet = set()
    for record in data_iterator:
        transaction = frozenset(record)
        transactionList.append(transaction)
        for item in transaction:
            itemSet.add(frozenset([item]))              # Generate 1-itemSets
    return itemSet, transactionList


def runApriori(data_iter, minSupport, minConfidence):
    """
    run the apriori algorithm. data_iter is a record iterator
    Return both:
     - items (tuple, support)
     - rules ((pretuple, posttuple), confidence)
    """
    itemSet, transactionList = getItemSetTransactionList(data_iter)

    freqSet = defaultdict(int)
    largeSet = dict()
    # Global dictionary which stores (key=n-itemSets,value=support)
    # which satisfy minSupport

    assocRules = dict()
    # Dictionary which stores Association Rules

    oneCSet = returnItemsWithMinSupport(itemSet,
                                        transactionList,
                                        minSupport,
                                        freqSet)

    currentLSet = oneCSet
    k = 2
    while(currentLSet != set([])):
        largeSet[k-1] = currentLSet
        currentLSet = joinSet(currentLSet, k)
        currentCSet = returnItemsWithMinSupport(currentLSet,
                                                transactionList,
                                                minSupport,
                                                freqSet)
        currentLSet = currentCSet
        k = k + 1

    def getSupport(item):
            """local function which Returns the support of an item"""
            return float(freqSet[item])/len(transactionList)

    toRetItems = []
    for key, value in largeSet.items():
        toRetItems.extend([(tuple(item), getSupport(item))
                           for item in value])

    toRetRules = []
    for key, value in largeSet.items()[1:]:
        for item in value:
            _subsets = map(frozenset, [x for x in subsets(item)])
            for element in _subsets:
                remain = item.difference(element)
                if len(remain) > 0:
                    confidence = getSupport(item)/getSupport(element)
                    if confidence >= minConfidence:
                        toRetRules.append(((tuple(element), tuple(remain)),
                                           confidence))
    return toRetItems, toRetRules


def printResults(items, rules):
    """prints the generated itemsets sorted by support and the confidence rules sorted by confidence"""
    dSupport = {}
    for item, support in sorted(items, key=lambda (item, support): support):
        dSupport[item] = support
        print("item: %s , %.3f" % (str(item), support))

    for rule, confidence in sorted(rules, key=lambda (rule, confidence): confidence):
        pre, post = rule
        tempRule=()
        tempRule+=pre
        tempRule+=post
        supportAimplikasiB = getSupportAimplikasiB(tempRule, dSupport)
        lift = supportAimplikasiB/(dSupport[pre]*dSupport[post])
        print("Rule: %s ==> %s : [confidence is %.3f, lift is %.3f]" % (str(pre), str(post), confidence, lift))

def getSupportAimplikasiB(A, B):
    rule = list(A)
    dict_support = B
    result = 0
    for index_dict_support in dict_support:
        list_index_dict_support = list(index_dict_support)
        check = []
        for data_index in list_index_dict_support:
            if data_index in rule and len(list_index_dict_support) >= len(rule):
                check.append(True)
            else:
                check.append(False)
        if(reduce(mul, check, 1)==True):
#             print(list_index_dict_support)
#             print(dict_support[index_dict_support])
            result = dict_support[index_dict_support]
    
    return result

def dataFromFile(fname):
        """Function which reads from the file and yields a generator"""
        file_iter = open(fname, 'rU')
        for line in file_iter:
                line = line.strip().rstrip(',')                         # Remove trailing comma
                record = frozenset(line.split(','))
                yield record

# %%
wb = load_workbook(filename = 'Data Alumni pelatihan phiton.xlsx')
sheet_ranges = wb['Sheet1']

df = pd.DataFrame(sheet_ranges.values)
df
# Out:
#              0         1                     2   \
# 0   DATA ALUMNI      None                  None
# 1          None      None                  None
# 2            No       Nim                 Nama
# 3          None      None                  None
# 4             1   9018263      Puguh Drajat E.P
# 5             2  12022030  Arsyad Cahya Subrata
# 6             3  12020021          Yesi Novela
# 7             4   9018269       Pandu Herwijaya
# 8             5   9018109        Anjar Prasetyo
# 9             6   9020026   Moh. Dadi Kurniawan
# 10            7  12018060        Martin Sarlina
# 11            8  11018022      Yan Adhi Permadi
# 12            9   9018212       Achicha Wahyuni
# 13           10   9018301   Yayan Tisna Permadi
# 14           11  12022020        Muh. Rama dhai
# 15           12  12022038           Nurwahyuddi
# 16           13  12019039          Agus Purnomo
# 17           14  11018111  M. Akhwan Zulfayandi
# 18           15   9018135   Yunita Tri Hernawai
# 19           16  12018161     Pratama Setya Aji
#
#                                   3                        4   \
# 0                               None                     None
# 1                               None                     None
# 2             Tempat & tanggal lahir     Fakultas/Ketrampilan
# 3                               None                     None
# 4         Purworejo, 4 November 1989  FTI / Teknik Iformatika
# 5               Bantul, 21 juni 1994     FTI / Teknik Elektro
# 6          Tempilang, 1 januari 1995                      FTI
# 7          Lampung, 19 Desember 1990   FTI/ Teknik Infomatika
# 8         Gunungkidul, 27 April 1991  FTI /Teknik Informatika
# 9          Savanajaya, 27 Maret 1992             FTI / Futsal
# 10              Lepak, 23 Maret 1994                      FTI
# 11              Jepara, 22 juni 1993                      FTI
# 12           Yogyakarta, 3 juni 1991          FTI/ Web Design
# 13      Purbalingga, 08 Oktober 1991   FTI/ Teknik Inormatika
# 14          Pekanbaru, 29 Maret 1992     FTI / Teknik Elektro
# 15  Dili, timor-timur/ 13 April 1995     FTI / Teknik Elektro
# 16            Klaten, 2 Agustus 1992     FTI/ Teknik Industri
# 17          Teros, 12 September 1992  FTI/ Teknik Informatika
# 18            Magelang, 20 Juni 1991  FTI/ Teknik Informatika
# 19         Sleman, 20 September 1994                      FTI
#
#                                                    5            6   \
# 0                                                None         None
# 1                                                None         None
# 2                                              Alamat  Tahun Masuk
# 3                                                None         None
# 4                                 Tangerang Rt. 01/ 0         2009
# 5    Karangpule Rt.01 , Tirtonirmolo , Kasihan Bantul         2012
# 6                                                None         2012
# 7                         Tamantirto, Kasihan ,Bantul         2009
# 8                             Umbulharjo , Yogyakarta         2009
# 9                   Saren Rt. 02 Rw. 01 Caturtunggal          2009
# 10                                                NTB         2012
# 11                                       Umbulharjo V         2011
# 12                    Noyokerten, Sendangirto, Berbah         2009
# 13                       Tajug, Rt.04/ 05 Purbalingga         2009
# 14     Karongan Rt/Rw. 04/11 Jogotirto, Berbah Sleman         2012
# 15                 Juru Gentong J V/407 C Banguntapan         2012
# 16                      Dukuh Glagahwangi, Polanharjo         2012
# 17  Jl. Peumnas gg. Indragiri Blok B/24, Condongcatur         2011
# 18                                           Magelang         2009
# 19           Jl. Affandi gg.Kamboja CTX.19 Yogyakarta         2012
#
#              7                 8                         9   ...      14  \
# 0          None              None                      None  ...    None
# 1          None              None                      None  ...    None
# 2   Tahun Lulus  Status Pekerjaan  Lama Masa Tunggu (bulan)  ...    None
# 3          None              None                      None  ...   Tidak
# 4          2016              None                       2.4  ...    None
# 5          2016              None                      None  ...    None
# 6          2016         Mahasiswa                       2.4  ...    None
# 7          2016              None                       2.4  ...    None
# 8          2016              None                      None  ...    None
# 9          2016              None                       2.4  ...    None
# 10         2016              None                       2.4  ...    None
# 11         2016        Wiraswasta                       2.4  ...    None
# 12         2016              Guru                         0  ...    None
# 13         2016              None                       2.4  ...    None
# 14         2016              None                       2.4  ...    None
# 15         2016         Mahasiswa                       2.4  ...    None
# 16         2016              None                       2.4  ...       v
# 17         2016              None                       2.4  ...    None
# 18         2016            Swasta                         1  ...    None
# 19         2016         Freelance                         0  ...       v
#
#                                                    15     16  \
# 0                                                None   None
# 1                                                None   None
# 2   2. Apakah SDMmempengaruhi proses belajar (misa...   None
# 3                                                  Ya  Tidak
# 4                                                   v   None
# 5                                                   v   None
# 6                                                   v   None
# 7                                                   v   None
# 8                                                   v   None
# 9                                                   v   None
# 10                                               None   None
# 11                                                  v   None
# 12                                                  v   None
# 13                                                  v   None
# 14                                                  v   None
# 15                                                  v   None
# 16                                                  v   None
# 17                                                  v   None
# 18                                                  v   None
# 19                                                  v   None
#
#                                                    17     18  \
# 0                                                None   None
# 1                                                None   None
# 2   3. Jika sudah bekerja apakah sesuai dengan  ju...   None
# 3                                                  Ya  Tidak
# 4                                                   v   None
# 5                                                   v   None
# 6                                                   v   None
# 7                                                   v   None
# 8                                                   v   None
# 9                                                None   None
# 10                                               None   None
# 11                                               None      v
# 12                                                  v   None
# 13                                                  v   None
# 14                                                  v   None
# 15                                                  v   None
# 16                                                  v   None
# 17                                                  v   None
# 18                                               None      v
# 19                                                  v   None
#
#                                                    19     20    21    22    23
# 0                                                None   None  None  None  None
# 1                                                None   None  None  None  None
# 2   4. Apakah Kurikulum pada data-data kuliah sesu...   None  None  None  None
# 3                                                  Ya  Tidak  None  None  None
# 4                                                   v   None  None  None  None
# 5                                                   v   None  None  None  None
# 6                                                   v   None  None  None  None
# 7                                                   v   None  None  None  None
# 8                                                   v   None  None  None  None
# 9                                                None   None  None  None  None
# 10                                               None   None  None  None  None
# 11                                               None      v  None  None  None
# 12                                                  v   None  None  None  None
# 13                                                  v   None  None  None  None
# 14                                                  v   None  None  None  None
# 15                                                  v   None  None  None  None
# 16                                                  v   None  None  None  None
# 17                                                  v   None  None  None  None
# 18                                                  v   None  None  None  None
# 19                                               None      v  None  None  None
#
# [20 rows x 24 columns]

# %%
d = df[4:20][[13,14,15,16,17,18,19,20]]

d.columns = ['A[Y]','A[T]','B[Y]','B[T]','C[Y]','C[T]','D[Y]','D[T]']
#A = FASILITAS MEMADAI
#B = SDM BERPENGARUH
#C = KERJA SESUAI JURUSAN
#D = KURIKULUM SESUAI DENGAN DUNIA KERJA
#---------------------------------------
# NOTE : Y = YA, T = TIDAK, B = BINGUNG

d
# Out:
#     A[Y]  A[T]  B[Y]  B[T]  C[Y]  C[T]  D[Y]  D[T]
# 4      v  None     v  None     v  None     v  None
# 5      v  None     v  None     v  None     v  None
# 6      v  None     v  None     v  None     v  None
# 7      v  None     v  None     v  None     v  None
# 8      v  None     v  None     v  None     v  None
# 9      v  None     v  None  None  None  None  None
# 10  None  None  None  None  None  None  None  None
# 11     v  None     v  None  None     v  None     v
# 12     v  None     v  None     v  None     v  None
# 13     v  None     v  None     v  None     v  None
# 14     v  None     v  None     v  None     v  None
# 15     v  None     v  None     v  None     v  None
# 16  None     v     v  None     v  None     v  None
# 17     v  None     v  None     v  None     v  None
# 18     v  None     v  None  None     v     v  None
# 19  None     v     v  None     v  None  None     v

# %%
list_data, temp_data = [], []

for index, data in d.iterrows():
    if (data['A[Y]'] == None) & (data['A[T]'] == None):
        temp_data.append('A[B]')
    elif data['A[Y]'] == 'v':
        temp_data.append('A[Y]')
    else:
        temp_data.append('A[T]')
    if (data['B[Y]'] == None) & (data['B[T]'] == None):
        temp_data.append('B[B]')
    elif data['B[Y]'] == 'v':
        temp_data.append('B[Y]')
    else:
        temp_data.append('B[T]')
    if (data['C[Y]'] == None) & (data['C[T]'] == None):
        temp_data.append('C[B]')
    elif data['C[Y]'] == 'v':
        temp_data.append('C[Y]')
    else:
        temp_data.append('C[T]')
    if (data['D[Y]'] == None) & (data['D[T]'] == None):
        temp_data.append('D[B]')
    elif data['D[Y]'] == 'v':
        temp_data.append('D[Y]')
    else:
        temp_data.append('D[T]')
        
    list_data.append(temp_data)
    temp_data = []

# %%
minSupport = 0.1
minConfidence = 0.2

items, rules = runApriori(list_data, minSupport, minConfidence)

printResults(items, rules)
# Out:
# item: ('C[B]',) , 0.125
# item: ('A[T]',) , 0.125
# item: ('C[T]',) , 0.125
# item: ('D[T]',) , 0.125
# item: ('D[B]',) , 0.125
# item: ('C[Y]', 'A[T]') , 0.125
# item: ('B[Y]', 'A[T]') , 0.125
# item: ('B[Y]', 'C[T]') , 0.125
# item: ('D[T]', 'B[Y]') , 0.125
# item: ('D[B]', 'C[B]') , 0.125
# item: ('A[Y]', 'C[T]') , 0.125
# item: ('A[Y]', 'B[Y]', 'C[T]') , 0.125
# item: ('B[Y]', 'C[Y]', 'A[T]') , 0.125
# item: ('A[Y]', 'C[Y]') , 0.625
# item: ('A[Y]', 'B[Y]', 'C[Y]') , 0.625
# item: ('A[Y]', 'C[Y]', 'D[Y]') , 0.625
# item: ('B[Y]', 'C[Y]', 'A[Y]', 'D[Y]') , 0.625
# item: ('A[Y]', 'D[Y]') , 0.688
# item: ('C[Y]', 'D[Y]') , 0.688
# item: ('A[Y]', 'B[Y]', 'D[Y]') , 0.688
# item: ('B[Y]', 'C[Y]', 'D[Y]') , 0.688
# item: ('C[Y]',) , 0.750
# item: ('D[Y]',) , 0.750
# item: ('B[Y]', 'C[Y]') , 0.750
# item: ('B[Y]', 'D[Y]') , 0.750
# item: ('A[Y]',) , 0.812
# item: ('A[Y]', 'B[Y]') , 0.812
# item: ('B[Y]',) , 0.938
# Rule: ('B[Y]',) ==> ('A[Y]', 'C[Y]') : [confidence is 0.667, lift is 1.067]
# Rule: ('B[Y]',) ==> ('A[Y]', 'C[Y]', 'D[Y]') : [confidence is 0.667, lift is 1.067]
# Rule: ('B[Y]',) ==> ('A[Y]', 'D[Y]') : [confidence is 0.733, lift is 1.067]
# Rule: ('B[Y]',) ==> ('C[Y]', 'D[Y]') : [confidence is 0.733, lift is 1.067]
# Rule: ('A[Y]',) ==> ('C[Y]',) : [confidence is 0.769, lift is 1.026]
# Rule: ('A[Y]',) ==> ('B[Y]', 'C[Y]') : [confidence is 0.769, lift is 1.026]
# Rule: ('A[Y]', 'B[Y]') ==> ('C[Y]',) : [confidence is 0.769, lift is 1.026]
# Rule: ('A[Y]',) ==> ('C[Y]', 'D[Y]') : [confidence is 0.769, lift is 1.119]
# Rule: ('A[Y]',) ==> ('B[Y]', 'C[Y]', 'D[Y]') : [confidence is 0.769, lift is 1.119]
# Rule: ('A[Y]', 'B[Y]') ==> ('C[Y]', 'D[Y]') : [confidence is 0.769, lift is 1.119]
# Rule: ('B[Y]',) ==> ('C[Y]',) : [confidence is 0.800, lift is 1.067]
# Rule: ('B[Y]',) ==> ('D[Y]',) : [confidence is 0.800, lift is 1.067]
# Rule: ('C[Y]',) ==> ('A[Y]',) : [confidence is 0.833, lift is 1.026]
# Rule: ('C[Y]',) ==> ('A[Y]', 'B[Y]') : [confidence is 0.833, lift is 1.026]
# Rule: ('B[Y]', 'C[Y]') ==> ('A[Y]',) : [confidence is 0.833, lift is 1.026]
# Rule: ('C[Y]',) ==> ('A[Y]', 'D[Y]') : [confidence is 0.833, lift is 1.212]
# Rule: ('D[Y]',) ==> ('A[Y]', 'C[Y]') : [confidence is 0.833, lift is 1.333]
# Rule: ('C[Y]',) ==> ('A[Y]', 'B[Y]', 'D[Y]') : [confidence is 0.833, lift is 1.212]
# Rule: ('D[Y]',) ==> ('A[Y]', 'B[Y]', 'C[Y]') : [confidence is 0.833, lift is 1.333]
# Rule: ('B[Y]', 'C[Y]') ==> ('A[Y]', 'D[Y]') : [confidence is 0.833, lift is 1.212]
# Rule: ('B[Y]', 'D[Y]') ==> ('A[Y]', 'C[Y]') : [confidence is 0.833, lift is 1.333]
# Rule: ('A[Y]',) ==> ('D[Y]',) : [confidence is 0.846, lift is 1.128]
# Rule: ('A[Y]',) ==> ('B[Y]', 'D[Y]') : [confidence is 0.846, lift is 1.128]
# Rule: ('A[Y]', 'B[Y]') ==> ('D[Y]',) : [confidence is 0.846, lift is 1.128]
# Rule: ('B[Y]',) ==> ('A[Y]',) : [confidence is 0.867, lift is 1.067]
# Rule: ('A[Y]', 'D[Y]') ==> ('C[Y]',) : [confidence is 0.909, lift is 1.212]
# Rule: ('C[Y]', 'D[Y]') ==> ('A[Y]',) : [confidence is 0.909, lift is 1.119]
# Rule: ('C[Y]', 'D[Y]') ==> ('A[Y]', 'B[Y]') : [confidence is 0.909, lift is 1.119]
# Rule: ('A[Y]', 'D[Y]') ==> ('B[Y]', 'C[Y]') : [confidence is 0.909, lift is 1.212]
# Rule: ('B[Y]', 'C[Y]', 'D[Y]') ==> ('A[Y]',) : [confidence is 0.909, lift is 1.119]
# Rule: ('A[Y]', 'B[Y]', 'D[Y]') ==> ('C[Y]',) : [confidence is 0.909, lift is 1.212]
# Rule: ('D[Y]',) ==> ('A[Y]',) : [confidence is 0.917, lift is 1.128]
# Rule: ('C[Y]',) ==> ('D[Y]',) : [confidence is 0.917, lift is 1.222]
# Rule: ('D[Y]',) ==> ('C[Y]',) : [confidence is 0.917, lift is 1.222]
# Rule: ('D[Y]',) ==> ('A[Y]', 'B[Y]') : [confidence is 0.917, lift is 1.128]
# Rule: ('B[Y]', 'D[Y]') ==> ('A[Y]',) : [confidence is 0.917, lift is 1.128]
# Rule: ('C[Y]',) ==> ('B[Y]', 'D[Y]') : [confidence is 0.917, lift is 1.222]
# Rule: ('D[Y]',) ==> ('B[Y]', 'C[Y]') : [confidence is 0.917, lift is 1.222]
# Rule: ('B[Y]', 'C[Y]') ==> ('D[Y]',) : [confidence is 0.917, lift is 1.222]
# Rule: ('B[Y]', 'D[Y]') ==> ('C[Y]',) : [confidence is 0.917, lift is 1.222]
# Rule: ('A[Y]',) ==> ('B[Y]',) : [confidence is 1.000, lift is 1.067]
# Rule: ('A[T]',) ==> ('C[Y]',) : [confidence is 1.000, lift is 1.333]
# Rule: ('C[Y]',) ==> ('B[Y]',) : [confidence is 1.000, lift is 1.067]
# Rule: ('D[Y]',) ==> ('B[Y]',) : [confidence is 1.000, lift is 1.067]
# Rule: ('A[T]',) ==> ('B[Y]',) : [confidence is 1.000, lift is 1.067]
# Rule: ('C[T]',) ==> ('B[Y]',) : [confidence is 1.000, lift is 1.067]
# Rule: ('D[T]',) ==> ('B[Y]',) : [confidence is 1.000, lift is 1.067]
# Rule: ('D[B]',) ==> ('C[B]',) : [confidence is 1.000, lift is 8.000]
# Rule: ('C[B]',) ==> ('D[B]',) : [confidence is 1.000, lift is 8.000]
# Rule: ('C[T]',) ==> ('A[Y]',) : [confidence is 1.000, lift is 1.231]
# Rule: ('A[Y]', 'C[Y]') ==> ('B[Y]',) : [confidence is 1.000, lift is 1.067]
# Rule: ('A[Y]', 'D[Y]') ==> ('B[Y]',) : [confidence is 1.000, lift is 1.067]
# Rule: ('C[Y]', 'D[Y]') ==> ('B[Y]',) : [confidence is 1.000, lift is 1.067]
# Rule: ('C[T]',) ==> ('A[Y]', 'B[Y]') : [confidence is 1.000, lift is 1.231]
# Rule: ('A[Y]', 'C[T]') ==> ('B[Y]',) : [confidence is 1.000, lift is 1.067]
# Rule: ('B[Y]', 'C[T]') ==> ('A[Y]',) : [confidence is 1.000, lift is 1.231]
# Rule: ('A[Y]', 'C[Y]') ==> ('D[Y]',) : [confidence is 1.000, lift is 1.333]
# Rule: ('A[T]',) ==> ('B[Y]', 'C[Y]') : [confidence is 1.000, lift is 1.333]
# Rule: ('B[Y]', 'A[T]') ==> ('C[Y]',) : [confidence is 1.000, lift is 1.333]
# Rule: ('C[Y]', 'A[T]') ==> ('B[Y]',) : [confidence is 1.000, lift is 1.067]
# Rule: ('A[Y]', 'C[Y]') ==> ('B[Y]', 'D[Y]') : [confidence is 1.000, lift is 1.333]
# Rule: ('A[Y]', 'B[Y]', 'C[Y]') ==> ('D[Y]',) : [confidence is 1.000, lift is 1.333]
# Rule: ('A[Y]', 'C[Y]', 'D[Y]') ==> ('B[Y]',) : [confidence is 1.000, lift is 1.067]
